# %%
import pandas as pd
import os
import sys

# %%
import urllib.request

# %%
os.chdir("C:\\Users\\venup\\Documents\\TShirt Graphic Classification")

# %%
data_train=pd.read_csv("Images_Train-1539865328888.csv")
data_validation=pd.read_csv("Images_Validation-1539865328888.csv")
data_test = pd.read_csv("Images_Test-1539865328888.csv")

# %%
lists_train = data_train.Sub_category.unique()
lists_validation = data_train.Sub_category.unique()
lists_test = data_test.Sub_category.unique()

# %%
os.mkdir("Images_Master")
os.mkdir("Images_Master//Train")
os.mkdir("Images_Master//Test")
os.mkdir("Images_Master//Test")

# %%
for ls in lists_train:
    os.mkdir("C:\\Users\\venup\\Documents\\TShirt Graphic Classification\\Images_Master\\Train\\"+ls)
for ls in lists_test:
    os.mkdir("C:\\Users\\venup\\Documents\\TShirt Graphic Classification\\Images_Master\\Test\\"+ls)
for ls in lists_validation:
    os.mkdir("C:\\Users\\venup\\Documents\\TShirt Graphic Classification\\Images_Master\\Validation\\"+ls)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-47-a72d2f916ee6> in <module>()
#       1 for ls in lists_train:
# ----> 2     os.mkdir("C:\\Users\\venup\\Documents\\TShirt Graphic Classification\\Images_Master\\Train\\"+ls)
#       3 for ls in lists_test:
#       4     os.mkdir("C:\\Users\\venup\\Documents\\TShirt Graphic Classification\\Images_Master\\Test\\"+ls)
#       5 for ls in lists_validation:
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'C:\\Users\\venup\\Documents\\TShirt Graphic Classification\\Images_Master\\Train\\Striped'

# %%
data_train.head()
# Out:
#                    Brand Category Gender  Color  \
# 0  HRX by Hrithik Roshan  Tshirts    Men  Black
# 1  HRX by Hrithik Roshan  Tshirts    Men  White
# 2             FOREVER 21  Tshirts    Men  Olive
# 3             FOREVER 21  Tshirts    Men  Brown
# 4             Pepe Jeans  Tshirts    Men  Green
#
#                                    Link_to_the_image Sub_category
# 0  http://myntra.myntassets.com/assets/images/879...        Solid
# 1  http://myntra.myntassets.com/assets/images/191...        Solid
# 2  http://myntra.myntassets.com/assets/images/209...        Solid
# 3  http://myntra.myntassets.com/assets/images/179...        Solid
# 4  http://myntra.myntassets.com/assets/images/127...       Floral

# %%
data_test.head()
# Out:
#                    Brand Category Gender      Color  \
# 0             FOREVER 21  Tshirts    Men      Black
# 1                Lacoste  Tshirts    Men  Navy Blue
# 2           Jack & Jones  Tshirts    Men     Yellow
# 3  HRX by Hrithik Roshan  Tshirts    Men       Blue
# 4             FOREVER 21  Tshirts  Women    Mustard
#
#                                    Link_to_the_image Sub_category
# 0  http://myntra.myntassets.com/assets/images/179...        Solid
# 1  http://myntra.myntassets.com/assets/images/202...        Solid
# 2  http://myntra.myntassets.com/assets/images/173...        Solid
# 3  http://myntra.myntassets.com/assets/images/113...        Solid
# 4  http://myntra.myntassets.com/assets/images/145...        Solid

# %%
i=0
for line in data_train.Link_to_the_image:
    try:
        print (line)
        urllib.request.urlretrieve(line, "C://Users//venup//Documents//TShirt Graphic Classification//Images_Master//Train//"+data.Sub_category[i]+"//img_" + str(i) + ".png")
        print ("Image saved for {0}".format(line))
    except (ConnectionError, ValueError, TypeError) as err:
        print ('Failed to open url.')
    except:
        print("Unexpected error:", sys.exc_info()[0])
        raise
    i=i+1
# Out:
# http://myntra.myntassets.com/assets/images/879072/2015/11/17/11447740258623-HRX-by-Hrithik-Roshan-Black-Active-T-shirt-9921447740258029-1.jpg
# Image saved for http://myntra.myntassets.com/assets/images/879072/2015/11/17/11447740258623-HRX-by-Hrithik-Roshan-Black-Active-T-shirt-9921447740258029-1.jpg
# http://myntra.myntassets.com/assets/images/1912862/2017/9/27/11506495922827-HRX-by-Hrithik-Roshan-Men-White-Solid-Round-Neck-T-shirt-3291506495922833-1.jpg
# Image saved for http://myntra.myntassets.com/assets/images/1912862/2017/9/27/11506495922827-HRX-by-Hrithik-Roshan-Men-White-Solid-Round-Neck-T-shirt-3291506495922833-1.jpg
# http://myntra.myntassets.com/assets/images/2098108/2017/10/4/11507117269393-FOREVER-21-Men-Olive-Green-Solid-Round-Neck-T-shirt-6701507117269217-1.jpg
# Image saved for http://myntra.myntassets.com/assets/images/2098108/2017/10/4/11507117269393-FOREVER-21-Men-Olive-Green-Solid-Round-Neck-T-shirt-6701507117269217-1.jpg
# ...

# %%
i=0
for line in data_test.Link_to_the_image:
    try:
        print (line)
        urllib.request.urlretrieve(line, "C://Users//venup//Documents//TShirt Graphic Classification//Images_Master//Test//"+data.Sub_category[i]+"//img_" + str(i) + ".png")
        print ("Image saved for {0}".format(line))
    except (ConnectionError, ValueError, TypeError) as err:
        print ('Failed to open url.')
    except:
        print("Unexpected error:", sys.exc_info()[0])
        raise
    i=i+1
# Out:
# http://myntra.myntassets.com/assets/images/1793459/2017/3/17/11489750536674-FOREVER-21-Men-Tshirts-5591489750536440-1.jpg
# Image saved for http://myntra.myntassets.com/assets/images/1793459/2017/3/17/11489750536674-FOREVER-21-Men-Tshirts-5591489750536440-1.jpg
# http://myntra.myntassets.com/assets/images/2021575/2017/8/1/11501571562590-Lacoste-L1212-polo-1521501571562482-1.jpg
# Image saved for http://myntra.myntassets.com/assets/images/2021575/2017/8/1/11501571562590-Lacoste-L1212-polo-1521501571562482-1.jpg
# http://myntra.myntassets.com/assets/images/1739672/2017/2/15/11487138397377-Jack--Jones-Men-Yellow-Solid-Round-Neck-T-Shirt-7101487138397150-1.jpg
# Image saved for http://myntra.myntassets.com/assets/images/1739672/2017/2/15/11487138397377-Jack--Jones-Men-Yellow-Solid-Round-Neck-T-Shirt-7101487138397150-1.jpg
# http://myntra.myntassets.com/assets/images/1131319/2016/3/24/11458815078726-HRX-by-Hrithik-Roshan-Blue-Active-T-shirt-4721458815078220-1.jpg
# ...

# %%
i=0
for line in data_test.Link_to_the_image:
    try:
        print (line)
        urllib.request.urlretrieve(line, "C://Users//venup//Documents//TShirt Graphic Classification//Images_Master//Validation//"+data.Sub_category[i]+"//img_" + str(i) + ".png")
        print ("Image saved for {0}".format(line))
    except (ConnectionError, ValueError, TypeError) as err:
        print ('Failed to open url.')
    except:
        print("Unexpected error:", sys.exc_info()[0])
        raise
    i=i+1
