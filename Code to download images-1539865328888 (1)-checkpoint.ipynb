# %%
import pandas as pd
import os
import sys

# %%
import urllib.request

# %%
os.chdir("C:\\Users\\venup\\Documents\\TShirt Graphic Classification")

# %%
data=pd.read_csv("Images_Train-1539865328888.csv")

# %%
data.Link_to_the_image[22:23]
# Out:
# 22    http://myntra.myntassets.com/images/style/prop...
# Name: Link_to_the_image, dtype: object

# %%
i=10
for line in data.Link_to_the_image:
    try:

        urllib.request.urlretrieve(line, "images/img_" + str(i) + ".png")
        print ("Image saved for {0}".format(line))
    except (ConnectionError, ValueError, TypeError) as err:
        print ('Failed to open url.')
    except:
        print("Unexpected error:", sys.exc_info()[0])
        raise
    i=i+1
# Out:
# Image saved for http://myntra.myntassets.com/assets/images/879072/2015/11/17/11447740258623-HRX-by-Hrithik-Roshan-Black-Active-T-shirt-9921447740258029-1.jpg
# Image saved for http://myntra.myntassets.com/assets/images/1912862/2017/9/27/11506495922827-HRX-by-Hrithik-Roshan-Men-White-Solid-Round-Neck-T-shirt-3291506495922833-1.jpg
# Image saved for http://myntra.myntassets.com/assets/images/2098108/2017/10/4/11507117269393-FOREVER-21-Men-Olive-Green-Solid-Round-Neck-T-shirt-6701507117269217-1.jpg
# Image saved for http://myntra.myntassets.com/assets/images/1793442/2017/3/17/11489750533356-FOREVER-21-Men-Tshirts-811489750533109-1.jpg
# Image saved for http://myntra.myntassets.com/assets/images/1270536/2016/7/15/11468571703744-Pepe-Jeans-Green--White-Printed-T-shirt-6321468571703727-1.jpg
# Image saved for http://myntra.myntassets.com/assets/images/2301915/2017/12/20/11513751370277-Pepe-Jeans-Men-Grey-Printed-Round-Neck-T-shirt-7531513751370173-1.jpg
# ...
